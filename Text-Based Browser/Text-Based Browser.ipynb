# %%
import sys
import os
import requests
from collections import deque
from bs4 import BeautifulSoup
from colorama import init, Fore

dir_name = sys.argv[1]

if not os.path.exists(dir_name):
    os.mkdir(dir_name)

history = deque()


def get_site_content(url):
    """
    output: string
    """
    r = requests.get(url).text
    soup = BeautifulSoup(r, 'html.parser')
    tags = ['h{}'.format(i) for i in range(1,7)]
    tags += ['p','a','ul','ol','li']
    content = soup.find_all(tags)
    output = ''
    for i in content:
        if i.name == 'a':
            output += Fore.BLUE + i.text
        else:    
            output += i.text
    return output


def save_site_content(data, path):
    history.append(path)
    with open(os.path.join(dir_name, path), "w") as f:
        f.write(data)


def go_site(site):
    address = site if site.startswith("https://") else f"https://{site}"
    site_content = get_site_content(address)
    save_site_content(site_content, site)
    print(site_content)
    

def go_back():
    history.pop()
    with open(os.path.join(dir_name, history.pop()), 'r') as f:
        print(f.read())


while True:
    command = input()
    if command == "exit":
        break
    if command == "back":
        go_back()
    elif "." in command:
        go_site(command)
    else:
        print("Error: Incorrect URL")
# Out:
# docs.python.org
# Navigation
#
# index
#
# modules |
#
# Python »
#
# 3.9.1 Documentation »
#
#
#
#
#
#
#
#
#
#
#
#          |
#
#
# indexindex
# modules |modulesPython »Python
# 3.9.1 Documentation »
#     3.9.1 Documentation
#
#
#
#
#
#
#
#
#
#          |
#     Python 3.9.1 documentation
#   Welcome! This is the documentation for Python 3.9.1.
#   Parts of the documentation:What's new in Python 3.9?
#  or all "What's new" documents since 2.0What's new in Python 3.9?all "What's new" documentsTutorial
# start hereTutorialLibrary Reference
# keep this under your pillowLibrary ReferenceLanguage Reference
# describes syntax and language elementsLanguage ReferencePython Setup and Usage
# how to use Python on different platformsPython Setup and UsagePython HOWTOs
# in-depth documents on specific topicsPython HOWTOsInstalling Python Modules
# installing from the Python Package Index & other sourcesInstalling Python ModulesDistributing Python Modules
# publishing modules for installation by othersDistributing Python ModulesExtending and Embedding
# tutorial for C/C++ programmersExtending and EmbeddingPython/C API
# reference for C/C++ programmersPython/C APIFAQs
# frequently asked questions (with answers!)FAQsIndices and tables:Global Module Index
# quick access to all modulesGlobal Module IndexGeneral Index
# all functions, classes, termsGeneral IndexGlossary
# the most important terms explainedGlossarySearch page
# search this documentationSearch pageComplete Table of Contents
# lists all sections and subsectionsComplete Table of ContentsMeta information:Reporting bugsReporting bugsContributing to DocsContributing to DocsAbout the documentationAbout the documentationHistory and License of PythonHistory and License of PythonCopyrightCopyrightDownloadDownload these documentsDownload these documentsDocs by version
# Python 3.10 (in development)
# Python 3.9 (stable)
# Python 3.8 (stable)
# Python 3.7 (security-fixes)
# Python 3.6 (security-fixes)
# Python 3.5 (EOL)
# Python 2.7 (EOL)
# All versions
# Python 3.10 (in development)Python 3.10 (in development)Python 3.9 (stable)Python 3.9 (stable)Python 3.8 (stable)Python 3.8 (stable)Python 3.7 (security-fixes)Python 3.7 (security-fixes)Python 3.6 (security-fixes)Python 3.6 (security-fixes)Python 3.5 (EOL)Python 3.5 (EOL)Python 2.7 (EOL)Python 2.7 (EOL)All versionsAll versionsOther resources
# PEP Index
# Beginner's Guide
# Book List
# Audio/Visual Talks
# Python Developerâs Guide
# PEP IndexPEP IndexBeginner's GuideBeginner's GuideBook ListBook ListAudio/Visual TalksAudio/Visual TalksPython Developerâs GuidePython Developerâs GuideNavigation
#
# index
#
# modules |
#
# Python »
#
# 3.9.1 Documentation »
#
#
#
#
#
#
#
#
#
#
#
#          |
#
#
# indexindex
# modules |modulesPython »Python
# 3.9.1 Documentation »
#     3.9.1 Documentation
#
#
#
#
#
#
#
#
#
#          |
#     CopyrightPlease donate.Found a bugSphinx
# exit
